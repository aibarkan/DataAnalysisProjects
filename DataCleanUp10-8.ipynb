# %%
import pandas as pd
#input file for cleaning
data=pd.read_excel(r"C:\Users\a653343\OneDrive - Owens & Minor\Desktop\DataFill10-7.xlsx")
export_file = r"C:\Users\a653343\OneDrive - Owens & Minor\Desktop\DataFill10-7.xlsx"
data = pd.DataFrame(data)
data.head()
# Out:
#          <ID>                                            <Name> <Parent ID>  \
# 0  H002003001                               Medical Exam Gloves     H002003
# 1     P110189                        PURPLE NITRILE* Exam Glove  H002003001
# 2     S102051  PURPLE NITRILE* Powder-Free Exam Gloves, M, Bulk     P110189
# 3     S102052  PURPLE NITRILE* Powder-Free Exam Gloves, L, Bulk     P110189
# 4     S102097       PURPLE NITRILE* Powder-Free Exam Gloves, XS     P110189
#
#   <Object Type Name> Acceptable Quality Level (AQL) Alcohol Content  \
# 0       PPHCategory3                            NaN             NaN
# 1            Product               Meets or Exceeds             NaN
# 2                SKU               Meets or Exceeds             NaN
# 3                SKU               Meets or Exceeds             NaN
# 4                SKU               Meets or Exceeds             NaN
#
#   Ambidextrous Applications Per Case ASTM D5151 Test Standards  \
# ...

# %%
#parent_sku_data = data[data['<Object Type Name>'].apply(lambda x: x in ['Product', 'SKU'])]
test_data = data[0:8]
test_data
# Out:
#          <ID>                                            <Name> <Parent ID>  \
# 0  H002003001                               Medical Exam Gloves     H002003
# 1     P110189                        PURPLE NITRILE* Exam Glove  H002003001
# 2     S102051  PURPLE NITRILE* Powder-Free Exam Gloves, M, Bulk     P110189
# 3     S102052  PURPLE NITRILE* Powder-Free Exam Gloves, L, Bulk     P110189
# 4     S102097       PURPLE NITRILE* Powder-Free Exam Gloves, XS     P110189
# 5     S102098        PURPLE NITRILE* Powder-Free Exam Gloves, S     P110189
# 6     S102099        PURPLE NITRILE* Powder-Free Exam Gloves, M     P110189
# 7     S102100        PURPLE NITRILE* Powder-Free Exam Gloves, L     P110189
#
#   <Object Type Name> Acceptable Quality Level (AQL) Alcohol Content  \
# 0       PPHCategory3                            NaN             NaN
# 1            Product               Meets or Exceeds             NaN
# 2                SKU               Meets or Exceeds             NaN
# ...

# %%
#ConsistentDict
grouped = test_data.groupby('<Parent ID>')
values = []
for parent_id, group in grouped:
    #if group[<Object Type Name>']
    #print(parent_id)
    consistent_cols = {}
    for col in group.columns:
        unique_values = group[col].dropna().unique()
        if len(unique_values) == 1 and len(group[col].dropna()) == group.shape[0]:
            consistent_cols[col] = unique_values[0]
            #print(group['<ID>'])
    #print(consistent_cols)
    id_value = group['<Parent ID>'].iloc[0]
    value_row = {'ID': id_value}
    value_row.update(consistent_cols)  
    values.append(value_row)

values_df = pd.DataFrame(values)
values_df
# Out:
#            ID        <ID>                      <Name> <Parent ID>  \
# 0     H002003  H002003001         Medical Exam Gloves     H002003
# 1  H002003001     P110189  PURPLE NITRILE* Exam Glove  H002003001
# 2     P110189         NaN                         NaN     P110189
#
#   <Object Type Name> Acceptable Quality Level (AQL) ASTM D5151 Test Standards  \
# 0       PPHCategory3                            NaN                       NaN
# 1            Product               Meets or Exceeds          Meets or Exceeds
# 2                SKU               Meets or Exceeds          Meets or Exceeds
#
#   ASTM D6319 Test Standards  \
# 0                       NaN
# 1          Meets or Exceeds
# 2          Meets or Exceeds
#
#         Biocompatibility - Based on the intended use  \
# 0                                                NaN
# 1  Non-irritating;Non-sensitizing;Not systemicall...
# 2  Non-irritating;Non-sensitizing;Not systemicall...
#
# ...

# %%
test_data
# Out:
#          <ID>                                            <Name> <Parent ID>  \
# 0  H002003001                               Medical Exam Gloves     H002003
# 1     P110189                        PURPLE NITRILE* Exam Glove  H002003001
# 2     S102051  PURPLE NITRILE* Powder-Free Exam Gloves, M, Bulk     P110189
# 3     S102052  PURPLE NITRILE* Powder-Free Exam Gloves, L, Bulk     P110189
# 4     S102097       PURPLE NITRILE* Powder-Free Exam Gloves, XS     P110189
# 5     S102098        PURPLE NITRILE* Powder-Free Exam Gloves, S     P110189
# 6     S102099        PURPLE NITRILE* Powder-Free Exam Gloves, M     P110189
# 7     S102100        PURPLE NITRILE* Powder-Free Exam Gloves, L     P110189
#
#   <Object Type Name> Acceptable Quality Level (AQL) Alcohol Content  \
# 0       PPHCategory3                            NaN             NaN
# 1            Product               Meets or Exceeds             NaN
# 2                SKU               Meets or Exceeds             NaN
# ...

# %%
for index, row in test_data.iterrows():
    #print(row['<ID>'])
    print(values_df['ID'])
    #set parent to parent
    if row['<ID>'] in values_df['ID']:
        print(row['<ID>'])
        consistent_values = values_df.loc[row['<ID>']]
        for col, val in values_df.items():
            row[col] = val
            #print(val)
# Out:
# 0       H002003
# 1    H002003001
# 2       P110189
# Name: ID, dtype: object
# 0       H002003
# 1    H002003001
# 2       P110189
# Name: ID, dtype: object
# 0       H002003
# 1    H002003001
# 2       P110189
# Name: ID, dtype: object
# 0       H002003
# 1    H002003001
# 2       P110189
# Name: ID, dtype: object
# 0       H002003
# 1    H002003001
# 2       P110189
# Name: ID, dtype: object
# 0       H002003
# 1    H002003001
# 2       P110189
# Name: ID, dtype: object
# 0       H002003
# 1    H002003001
# 2       P110189
# Name: ID, dtype: object
# 0       H002003
# 1    H002003001
# 2       P110189
# Name: ID, dtype: object

# %%
# Grouping the data by '<Parent ID>'
grouped = test_data.groupby('<Parent ID>')
values = []

for parent_id, group in grouped:
    consistent_cols = {}
    
    # Iterate over all columns to check for consistency within each group (except for '<ID>' and '<Parent ID>')
    for col in group.columns:
        if col not in ['<ID>', '<Parent ID>']:
            unique_values = group[col].dropna().unique()
            
            # If there's only one unique value and it exists in all rows, mark it as consistent
            if len(unique_values) == 1 and len(group[col].dropna()) == group.shape[0]:
                consistent_cols[col] = unique_values[0]  # Store the consistent value
    
    # Only create a value_row if there are consistent columns
    if consistent_cols:
        value_row = {'<Parent ID>': parent_id}  # Start with the Parent ID
        value_row.update(consistent_cols)  # Add the consistent columns to the row
        
        # Append the value_row to the final list of values
        values.append(value_row)

# Convert the final list of values into a DataFrame
if values:
    values_df = pd.DataFrame(values)
else:
    values_df = pd.DataFrame()

# Display the resulting DataFrame
values_df
# Out:
#   <Parent ID>                      <Name> <Object Type Name>  \
# 0     H002003         Medical Exam Gloves       PPHCategory3
# 1  H002003001  PURPLE NITRILE* Exam Glove            Product
# 2     P110189                         NaN                SKU
#
#   Acceptable Quality Level (AQL) ASTM D5151 Test Standards  \
# 0                            NaN                       NaN
# 1               Meets or Exceeds          Meets or Exceeds
# 2               Meets or Exceeds          Meets or Exceeds
#
#   ASTM D6319 Test Standards  \
# 0                       NaN
# 1          Meets or Exceeds
# 2          Meets or Exceeds
#
#         Biocompatibility - Based on the intended use  \
# 0                                                NaN
# 1  Non-irritating;Non-sensitizing;Not systemicall...
# 2  Non-irritating;Non-sensitizing;Not systemicall...
#
#   Biocompatibility - ISO Standard for Primary Skin Irritation & Sensitivity  \
# 0                                                NaN
# ...

# %%
#ConsistentDict
grouped = test_data.groupby('<Parent ID>')
values = []
for parent_id, group in grouped:
    consistent_cols = {}
    for col in group.columns:
        unique_values = group[col].dropna().unique()
        #print(col, len(group[col].dropna()),group.shape[0])
        #print(unique_values)
        if len(unique_values) == 1 and len(group[col].dropna()) == group.shape[0]:
            #print(col, len(group[col].dropna()),group.shape[0])
            consistent_cols[col] = unique_values
            value_row.update(consistent_cols)
       # print(consistent_cols)
    if consistent_cols:
        value_row = {'parent_id': parent_id}
        values.append(value_row)
if values:
    values_df = pd.DataFrame(values)
else:
    values_df = pd.DataFrame()

values_df
# Out:
#     parent_id       <ID>                        <Name>   <Parent ID>  \
# 0     H002003  [P110189]  [PURPLE NITRILE* Exam Glove]  [H002003001]
# 1  H002003001        NaN                           NaN     [P110189]
# 2     P110189        NaN                           NaN           NaN
#
#   <Object Type Name> Acceptable Quality Level (AQL) ASTM D5151 Test Standards  \
# 0          [Product]             [Meets or Exceeds]        [Meets or Exceeds]
# 1              [SKU]             [Meets or Exceeds]        [Meets or Exceeds]
# 2                NaN                            NaN                       NaN
#
#   ASTM D6319 Test Standards  \
# 0        [Meets or Exceeds]
# 1        [Meets or Exceeds]
# 2                       NaN
#
#         Biocompatibility - Based on the intended use  \
# 0  [Non-irritating;Non-sensitizing;Not systemical...
# 1  [Non-irritating;Non-sensitizing;Not systemical...
# 2                                                NaN
#
# ...

# %%
values = []

# Iterate over rows where '<Object Type Name>' is 'SKU'
for index, row in test_data[test_data['<Object Type Name>'] == 'SKU'].iterrows():
    consistent_cols = {}

    # Iterate through columns in the current row (except for '<ID>' and '<Parent ID>')
    for col in test_data.columns:
            unique_values = test_data[col].dropna().unique()  # Get unique non-null values for the column

            # Check if the column has only one unique value and it's present in all rows
            if len(unique_values) == 1 and len(test_data[col].dropna()) == test_data.shape[0]:
                consistent_cols[col] = unique_values[0]  # Store consistent value

    # Create a value row for the current SKU
    value_row = {'ID': row['<Parent ID>']}  # Use Parent ID as reference
    value_row.update(consistent_cols)  # Add consistent columns
    
    # Append the row to the final list of values
    values.append(value_row)

# Convert the final list of values into a DataFrame
values_df = pd.DataFrame(values)

# Display the resulting DataFrame
values_df
# Out:
#         ID
# 0  P110189
# 1  P110189
# 2  P110189
# 3  P110189
# 4  P110189
# 5  P110189

# %%
values = []
for index, row in test_data[test_data['<Object Type Name>'] == 'SKU'].iterrows():
    consistent_cols = {}
    for col in test_data.columns:
        unique_values = test_data[col].dropna().unique()
        #print(len(test_data[col].dropna()))
        print(test_data.shape[0])
        #if len(unique_values) == 1 and :
            #print(unique_values)
# Out:
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# ...

# %%
values = []
for index, row in test_data[test_data['<Object Type Name>'] == 'SKU'].iterrows():
    consistent_cols = {}
    for col in index.columns:
        unique_values = index[col].dropna().unique()
        if len(unique_values) == 1 and len(group[col].dropna())==index.shape[0]:
            consistent_cols[col] = unique_values[0]
    value_row = {'ID': row['<Parent ID>']}
    value_row.update(consistent_cols)  
    values.append(value_row)
values_df = pd.DataFrame(values)

# %%
#ConsistentDict

#for x in data[object type = sku]
#set id = parent it


grouped = test_data.groupby(['<Parent ID>','<ID>'])
values = []
for ids, group in grouped:
    #if object type = sku
    #if id in parentid
    print(ids)
    consistent_cols = {}
    for col in group.columns:
        #print(parent_id,col)
        unique_values = group[col].dropna().unique()
        if len(unique_values) == 1 and len(group[col].dropna())>1:
            consistent_cols[col] = unique_values[0]''
            #print(parent_id, consistent_cols)
    #print(consistent_cols)
# Out:
# ('H002003', 'H002003001')
# ('H002003001', 'P110189')
# ('P110189', 'S102051')
# ('P110189', 'S102052')
# ('P110189', 'S102097')
# ('P110189', 'S102098')
# ('P110189', 'S102099')
# ('P110189', 'S102100')

# %%
#ConsistentDict

#for x in data[object type = sku]
#set id = parent it


grouped = test_data.groupby('<Parent ID>')
values = []
for ids, group in grouped:
    #if object type = sku
    #if id in parentid
    print(ids)
    consistent_cols = {}
    for col in group.columns:
        #print(parent_id,col)
        unique_values = group[col].dropna().unique()
        if len(unique_values) == 1 and len(group[col].dropna())>1:
            consistent_cols[col] = unique_values[0]
            print(parent_id, consistent_cols)
    #print(consistent_cols)
# Out:
# H002003
# H002003001
# P110189

# %%
#ConsistentDict
grouped = test_data.groupby('<Parent ID>')
#print(pd.DataFrame(grouped))
values = []
for parent_id, group in grouped:
    #print(parent_id)
    #if group[<Object Type Name>']
    #print(parent_id)
    consistent_cols = {}
    for col in group.columns:
        unique_values = group[col].dropna().unique()
        if len(unique_values) == 1 and len(group[col].dropna()) == group.shape[0]:
            consistent_cols[col] = unique_values[0]
            #print(group['<ID>'])
    #print(consistent_cols)
    group.drop('<ID>', axis=1, inplace=True)
    #group..drop('<Name>', axis=1, inplace=True)
    id_value = group['<Parent ID>'].iloc[0]
    value_row = {'<ID>': id_value}
    value_row.update(consistent_cols)  
    values.append(value_row)

if values:
    values_df = pd.DataFrame(values)
else:
    values_df = pd.DataFrame()
values_df = values_df[values_df['<Object Type Name>'] == 'SKU']
values_df
# Out:
#       <ID> <Name> <Parent ID> <Object Type Name>  \
# 2  P110189    NaN     P110189                SKU
#
#   Acceptable Quality Level (AQL) ASTM D5151 Test Standards  \
# 2               Meets or Exceeds          Meets or Exceeds
#
#   ASTM D6319 Test Standards  \
# 2          Meets or Exceeds
#
#         Biocompatibility - Based on the intended use  \
# 2  Non-irritating;Non-sensitizing;Not systemicall...
#
#   Biocompatibility - ISO Standard for Primary Skin Irritation & Sensitivity  \
# 2                                   Meets or Exceeds
#
#   Biocompatibility - Standards that apply  ... Material.1  \
# 2               ISO 10993-10;ISO 10993-11  ...    Nitrile
#
#   Not Made with Natural Rubber Latex.1 Powder Free.1 Primary Product Color  \
# 2                                 True           Yes                Purple
#
#   Requires Sterilization Prior to Use.1 Single Use.1 Sterile.1  \
# 2                                 False         True        No
#
# ...

# %%
test_data
# Out:
#          <ID>                                            <Name> <Parent ID>  \
# 0  H002003001                               Medical Exam Gloves     H002003
# 1     P110189                        PURPLE NITRILE* Exam Glove  H002003001
# 2     S102051  PURPLE NITRILE* Powder-Free Exam Gloves, M, Bulk     P110189
# 3     S102052  PURPLE NITRILE* Powder-Free Exam Gloves, L, Bulk     P110189
# 4     S102097       PURPLE NITRILE* Powder-Free Exam Gloves, XS     P110189
# 5     S102098        PURPLE NITRILE* Powder-Free Exam Gloves, S     P110189
# 6     S102099        PURPLE NITRILE* Powder-Free Exam Gloves, M     P110189
# 7     S102100        PURPLE NITRILE* Powder-Free Exam Gloves, L     P110189
#
#   <Object Type Name> Acceptable Quality Level (AQL) Alcohol Content  \
# 0       PPHCategory3                            NaN             NaN
# 1            Product               Meets or Exceeds             NaN
# 2                SKU               Meets or Exceeds             NaN
# ...

# %%
for index, test_row in test_data.iterrows():
    data_id = test_row['<ID>']
    
    # Check if data_id exists in values_df['<ID>']
    if data_id in values_df['<ID>'].values:
        # Get the matching row from values_df where <ID> matches test_data's data_id
        matching_row = values_df[values_df['<ID>'] == data_id].iloc[0]
        
        # Iterate over columns and update test_data row with values from values_df row if they differ
        for col in test_data.columns:
            if col in values_df.columns:
                test_value = test_data.at[index, col]
                values_value = matching_row[col]
                
                # Update test_data if values are different
                if pd.isna(test_value):
                    test_data.at[index, col] = values_value

# Display the updated test_data
test_data
# Out:
#          <ID>                                            <Name> <Parent ID>  \
# 0  H002003001                               Medical Exam Gloves     H002003
# 1     P110189                        PURPLE NITRILE* Exam Glove  H002003001
# 2     S102051  PURPLE NITRILE* Powder-Free Exam Gloves, M, Bulk     P110189
# 3     S102052  PURPLE NITRILE* Powder-Free Exam Gloves, L, Bulk     P110189
# 4     S102097       PURPLE NITRILE* Powder-Free Exam Gloves, XS     P110189
# 5     S102098        PURPLE NITRILE* Powder-Free Exam Gloves, S     P110189
# 6     S102099        PURPLE NITRILE* Powder-Free Exam Gloves, M     P110189
# 7     S102100        PURPLE NITRILE* Powder-Free Exam Gloves, L     P110189
#
#   <Object Type Name> Acceptable Quality Level (AQL) Alcohol Content  \
# 0       PPHCategory3                            NaN             NaN
# 1            Product               Meets or Exceeds             NaN
# 2                SKU               Meets or Exceeds             NaN
# ...

# %%
test_data.update(values_df)

# %%
test_data
# Out:
#          <ID>                                            <Name> <Parent ID>  \
# 0  H002003001                               Medical Exam Gloves     H002003
# 1     P110189                        PURPLE NITRILE* Exam Glove  H002003001
# 2     P110189  PURPLE NITRILE* Powder-Free Exam Gloves, M, Bulk     P110189
# 3     S102052  PURPLE NITRILE* Powder-Free Exam Gloves, L, Bulk     P110189
# 4     S102097       PURPLE NITRILE* Powder-Free Exam Gloves, XS     P110189
# 5     S102098        PURPLE NITRILE* Powder-Free Exam Gloves, S     P110189
# 6     S102099        PURPLE NITRILE* Powder-Free Exam Gloves, M     P110189
# 7     S102100        PURPLE NITRILE* Powder-Free Exam Gloves, L     P110189
#
#   <Object Type Name> Acceptable Quality Level (AQL) Alcohol Content  \
# 0       PPHCategory3                            NaN             NaN
# 1            Product               Meets or Exceeds             NaN
# 2                SKU               Meets or Exceeds             NaN
# ...

# %%
merged_df = test_data.merge(values_df, on=['<ID>'], how='left', suffixes=('', '_new'))

# %%
merged_df
# Out:
#          <ID>                                            <Name> <Parent ID>  \
# 0  H002003001                               Medical Exam Gloves     H002003
# 1     P110189                        PURPLE NITRILE* Exam Glove  H002003001
# 2     S102051  PURPLE NITRILE* Powder-Free Exam Gloves, M, Bulk     P110189
# 3     S102052  PURPLE NITRILE* Powder-Free Exam Gloves, L, Bulk     P110189
# 4     S102097       PURPLE NITRILE* Powder-Free Exam Gloves, XS     P110189
# 5     S102098        PURPLE NITRILE* Powder-Free Exam Gloves, S     P110189
# 6     S102099        PURPLE NITRILE* Powder-Free Exam Gloves, M     P110189
# 7     S102100        PURPLE NITRILE* Powder-Free Exam Gloves, L     P110189
#
#   <Object Type Name> Acceptable Quality Level (AQL) Alcohol Content  \
# 0       PPHCategory3                            NaN             NaN
# 1            Product               Meets or Exceeds             NaN
# 2                SKU               Meets or Exceeds             NaN
# ...

# %%
merged_df
# Out:
#          <ID>                                            <Name> <Parent ID>  \
# 0  H002003001                               Medical Exam Gloves     H002003
# 1     P110189                        PURPLE NITRILE* Exam Glove  H002003001
# 2     S102051  PURPLE NITRILE* Powder-Free Exam Gloves, M, Bulk     P110189
# 3     S102052  PURPLE NITRILE* Powder-Free Exam Gloves, L, Bulk     P110189
# 4     S102097       PURPLE NITRILE* Powder-Free Exam Gloves, XS     P110189
# 5     S102098        PURPLE NITRILE* Powder-Free Exam Gloves, S     P110189
# 6     S102099        PURPLE NITRILE* Powder-Free Exam Gloves, M     P110189
# 7     S102100        PURPLE NITRILE* Powder-Free Exam Gloves, L     P110189
#
#   <Object Type Name> Acceptable Quality Level (AQL) Alcohol Content  \
# 0       PPHCategory3                            NaN             NaN
# 1            Product               Meets or Exceeds             NaN
# 2                SKU               Meets or Exceeds             NaN
# ...

# %%
merged_df = test_data.merge(values_df, on=['<ID>'], how='left')

# %%
merged_df
# Out:
#          <ID>                                          <Name>_x <Parent ID>_x  \
# 0  H002003001                               Medical Exam Gloves       H002003
# 1     P110189                        PURPLE NITRILE* Exam Glove    H002003001
# 2     S102051  PURPLE NITRILE* Powder-Free Exam Gloves, M, Bulk       P110189
# 3     S102052  PURPLE NITRILE* Powder-Free Exam Gloves, L, Bulk       P110189
# 4     S102097       PURPLE NITRILE* Powder-Free Exam Gloves, XS       P110189
# 5     S102098        PURPLE NITRILE* Powder-Free Exam Gloves, S       P110189
# 6     S102099        PURPLE NITRILE* Powder-Free Exam Gloves, M       P110189
# 7     S102100        PURPLE NITRILE* Powder-Free Exam Gloves, L       P110189
#
#   <Object Type Name>_x Acceptable Quality Level (AQL)_x Alcohol Content  \
# 0         PPHCategory3                              NaN             NaN
# 1              Product                 Meets or Exceeds             NaN
# ...

# %%
merged_df = test_data.merge(values_df, on=['<ID>'], how='left', suffixes=('', '_new'))

# %%
merged_df = test_data.merge(values_df, left_on='<Parent ID>', right_on='<ID>', how='left', suffixes=('', '_parent'))

# %%
#where parentid = sku_id, set values = '[delete]'

# %%
merged_df
# Out:
#          <ID>                                            <Name> <Parent ID>  \
# 0  H002003001                               Medical Exam Gloves     H002003
# 1     P110189                        PURPLE NITRILE* Exam Glove  H002003001
# 2     S102051  PURPLE NITRILE* Powder-Free Exam Gloves, M, Bulk     P110189
# 3     S102052  PURPLE NITRILE* Powder-Free Exam Gloves, L, Bulk     P110189
# 4     S102097       PURPLE NITRILE* Powder-Free Exam Gloves, XS     P110189
# 5     S102098        PURPLE NITRILE* Powder-Free Exam Gloves, S     P110189
# 6     S102099        PURPLE NITRILE* Powder-Free Exam Gloves, M     P110189
# 7     S102100        PURPLE NITRILE* Powder-Free Exam Gloves, L     P110189
#
#   <Object Type Name> Acceptable Quality Level (AQL) Alcohol Content  \
# 0       PPHCategory3                            NaN             NaN
# 1            Product               Meets or Exceeds             NaN
# 2                SKU               Meets or Exceeds             NaN
# ...
